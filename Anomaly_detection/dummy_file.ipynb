# %%
import pandas as pd

# %%
test_df = pd.read_json('new_test.json')

# %%
test_df
# Out:
#       Unnamed: 0                             ts       id.orig_h  \
# 0              4  2020-09-09 06:59:49.488742113      10.1.1.110
# 1              5  2020-09-09 06:59:49.489418983  203.223.175.67
# 2              8  2020-09-09 06:59:49.519808053        10.3.3.2
# 3              9  2020-09-09 06:59:54.039248943  203.223.175.67
# 4             12  2020-09-09 06:59:49.549081087      10.1.1.110
# ...          ...                            ...             ...
# 4995        8050  2020-09-09 07:01:34.391918898       10.1.1.38
# 4996        8054  2020-09-09 07:01:33.664387941  203.223.175.67
# 4997        8055  2020-09-09 07:01:33.663949966      10.1.1.141
# 4998        8056  2020-09-09 07:01:31.759021997  203.223.175.67
# 4999        8057  2020-09-09 07:01:31.758567095      10.1.1.141
#
#                      uid      id.resp_h proto  id.resp_p  id.orig_p  \
# 0     CbnVVz3MAccMVaX3Lh        8.8.4.4   udp         53      50363
# ...

# %%
test_df = test_df.iloc[:1001]

# %%
import random
rnd_lst = random.sample(range(10,1001),50)

# %%
test_df.iloc[rnd_lst,12] =7000
# Out:
# C:\Users\atti-001\Anaconda3\lib\site-packages\pandas\core\indexing.py:1719: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
test_df.iloc[rnd_lst]['duration']
# Out:
# 148    7000.0
# 686    7000.0
# 235    7000.0
# 231    7000.0
# 244    7000.0
# 866    7000.0
# 139    7000.0
# 22     7000.0
# 389    7000.0
# 417    7000.0
# 945    7000.0
# 671    7000.0
# 808    7000.0
# 722    7000.0
# 12     7000.0
# 91     7000.0
# 576    7000.0
# 666    7000.0
# 848    7000.0
# 254    7000.0
# 986    7000.0
# 932    7000.0
# 615    7000.0
# 523    7000.0
# 365    7000.0
# 973    7000.0
# 534    7000.0
# 592    7000.0
# 14     7000.0
# 963    7000.0
# 854    7000.0
# 24     7000.0
# 513    7000.0
# 981    7000.0
# 991    7000.0
# 753    7000.0
# 86     7000.0
# 774    7000.0
# 911    7000.0
# 680    7000.0
# 488    7000.0
# 30     7000.0
# 647    7000.0
# 718    7000.0
# 39     7000.0
# 898    7000.0
# 427    7000.0
# 545    7000.0
# 367    7000.0
# 176    7000.0
# Name: duration, dtype: float64

# %%
test_df.to_json()
# Out:
# '{"Unnamed: 0":{"0":4,"1":5,"2":8,"3":9,"4":12,"5":13,"6":16,"7":17,"8":18,"9":19,"10":20,"11":21,"12":22,"13":23,"14":24,"15":31,"16":32,"17":33,"18":34,"19":37,"20":40,"21":42,"22":46,"23":47,"24":48,"25":49,"26":52,"27":53,"28":56,"29":57,"30":59,"31":67,"32":68,"33":74,"34":75,"35":78,"36":79,"37":80,"38":85,"39":86,"40":87,"41":88,"42":89,"43":90,"44":91,"45":92,"46":93,"47":95,"48":96,"49":99,"50":100,"51":101,"52":102,"53":107,"54":108,"55":110,"56":111,"57":112,"58":113,"59":117,"60":118,"61":125,"62":126,"63":129,"64":132,"65":141,"66":142,"67":144,"68":145,"69":146,"70":149,"71":150,"72":151,"73":152,"74":153,"75":155,"76":157,"77":161,"78":162,"79":165,"80":166,"81":167,"82":171,"83":172,"84":175,"85":178,"86":179,"87":182,"88":185,"89":186,"90":189,"91":190,"92":191,"93":196,"94":197,"95":198,"96":199,"97":200,"98":201,"99":202,"100":203,"101":204,"102":205,"103":212,"104":213,"105":218,"106":219,"107":220,"108":221,"109":222,"110":225,"111":226,"112":227,"113":229,"114":
# ...
